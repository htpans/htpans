# %%
# !pip install imgaug
# %tensorflow_version 1.x
import tensorflow as tf
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !cp -r '/content/gdrive/My Drive/YOLO_TrainingTools/.'  /content/.
# !mkdir /content/train_annotate/
# !mkdir /content/train_images/
# !cp -r '/content/gdrive/My Drive/train_annotate/.'  /content/train_annotate/
# !cp -r '/content/gdrive/My Drive/train_images/.'  /content/train_images/
#%tensorflow_version 1.x
# !python train.py -c config_updated.json
