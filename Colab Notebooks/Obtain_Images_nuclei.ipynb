# %%
# !pip install imgaug
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !mkdir  /content/StitchedImages/
# !cp -r '/content/gdrive/My Drive/Selection_Images/.'   /content/StitchedImages/
# !mkdir /content/LDModel/
# !cp -r '/content/gdrive/My Drive/LD_Model/.'   /content/LDModel/
# !cp -r '/content/gdrive/My Drive/YOLO_TrainingTools/.'   /content/
# !python Scoring_Cells.py -c config.json  -w full_yolo_liveNuclei.h5  -i /content/StitchedImages/
