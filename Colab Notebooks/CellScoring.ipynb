# %%
# !pip install imgaug
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !mkdir /content/LDModel/
# !cp -r '/content/gdrive/My Drive/LDModel_ForScoring/.' /content/LDModel/


# !cp -r '/content/gdrive/My Drive/Scoring_Tools/.'  /content/.
# !cp -r '/content/gdrive/My Drive/Trained_Yolo/.'  /content/.


# !mkdir /content/AlignStacks/
# !cp -r '/content/gdrive/My Drive/AlignStacks/.'  /content/AlignStacks/

# !python Scoring_Cells.py -c config.json -w full_yolo_fl.h5 -i /content/AlignStacks/
