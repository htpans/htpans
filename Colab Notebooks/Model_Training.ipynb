# %%
# !pip install imgaug
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !unzip '/content/gdrive/My Drive/Data.zip'

# !mkdir /content/LD_model_Built/
# !cp -r '/content/gdrive/My Drive/LD_model_built/.' /content/LD_model_Built/
# !mkdir /content/edclasses/
# !cp -r '/content/gdrive/My Drive/edclasses/.' /content/edclasses/
# !cp -r '/content/gdrive/My Drive/CNN_Training/.' /content/
# %tensorflow_version 1.x
import tensorflow as tf

! python live_dead_train_CNN.py
