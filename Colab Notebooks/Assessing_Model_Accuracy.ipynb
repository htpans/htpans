# %%
# !pip install imgaug
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !cp -r '/content/gdrive/My Drive/CNN_Training/.'  /content/.
# !cp -r '/content/gdrive/My Drive/EDclasses/.'  /content/.

# !python Model_accuracy.py -i '/content/gdrive/My Drive/TestImages/' -m '/content/gdrive/My Drive/LDmodel/'  --eval_all

# %%
# !cp -r /content/Eval_Data_All.csv '/content/gdrive/My Drive/Eval_Data_All.csv'
